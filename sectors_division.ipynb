# %%
import pandas as pd

# %%
stocks_info = pd.read_csv(r'data\sp500-with-gics.csv')
stocks_info
# Out:
#      Unnamed: 0 Ticker          CompanyName                  Sector  \
# 0             0    MMM           3M Company             Industrials
# 1             1    ABT  Abbott Laboratories             Health Care
# 2             2   ABBV          AbbVie Inc.             Health Care
# 3             3   ABMD          ABIOMED Inc             Health Care
# 4             4    ACN        Accenture plc  Information Technology
# ..          ...    ...                  ...                     ...
# 500         500    YUM      Yum! Brands Inc  Consumer Discretionary
# 501         501   ZBRA   Zebra Technologies  Information Technology
# 502         502    ZBH        Zimmer Biomet             Health Care
# 503         503   ZION        Zions Bancorp              Financials
# 504         504    ZTS               Zoetis             Health Care
#
#                             SubIndustry                HQLocation  \
# 0              Industrial Conglomerates       St. Paul, Minnesota
# ...

# %%
unique_sectors_list = stocks_info['Sector'].unique().tolist()
unique_sub_industries_list = stocks_info['SubIndustry'].unique().tolist()

# %%
unique_sectors_list
# Out:
# ['Industrials',
#  'Health Care',
#  'Information Technology',
#  'Communication Services',
#  'Consumer Discretionary',
#  'Utilities',
#  'Financials',
#  'Materials',
#  'Real Estate',
#  'Consumer Staples',
#  'Energy']

# %%
unique_sub_industries_list
# Out:
# ['Industrial Conglomerates',
#  'Health Care Equipment',
#  'Pharmaceuticals',
#  'IT Consulting & Other Services',
#  'Interactive Home Entertainment',
#  'Application Software',
#  'Semiconductors',
#  'Automotive Retail',
#  'Independent Power Producers & Energy Traders',
#  'Life & Health Insurance',
#  'Industrial Gases',
#  'Internet Services & Infrastructure',
#  'Airlines',
#  'Specialty Chemicals',
#  'Office REITs',
#  'Health Care Supplies',
#  'Building Products',
#  'Electric Utilities',
#  'Property & Casualty Insurance',
#  'Interactive Media & Services',
#  'Tobacco',
#  'Internet & Direct Marketing Retail',
#  'Paper Packaging',
#  'Multi-Utilities',
#  'Consumer Finance',
#  'Specialized REITs',
#  'Water Utilities',
#  'Asset Management & Custody Banks',
#  'Health Care Distributors',
#  'Electrical Components & Equipment',
#  'Biotechnology',
#  'Electronic Components',
#  'Managed Health Care',
#  'Insurance Brokers',
#  'Oil & Gas Exploration & Production',
# ...
